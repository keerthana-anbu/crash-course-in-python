# %% [markdown]
# # PANDAS
# ## series

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
a=pd.Series([1,2,3,4,5],index=['A','B','C','D','E'])

# %%
a
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %% [markdown]
# # candidate profile in series

# %%
keer=pd.Series([19,8.73,'are',['maths','dia']],index=['age','cgpa','designation','fav sub'])

# %%
keer
# Out:
# age                      19
# cgpa                   8.73
# designation             are
# fav sub        [maths, dia]
# dtype: object

# %% [markdown]
# # data for dataframe
# ### we use pandas.DataFrame

# %%
data={'drama':['hidden love','gagnam beauty','true beauty','penthouse'],'ratings':[10,9,10,10]}

# %%
df=pd.DataFrame(data,columns=['drama','ratings'])

# %%
df
# Out:
#            drama  ratings
# 0    hidden love       10
# 1  gagnam beauty        9
# 2    true beauty       10
# 3      penthouse       10

# %% [markdown]
# # dataframe with random numbers

# %%
import numpy as np

# %%
rm=pd.DataFrame(np.random.randint(0,300,size=(20,4)),columns=list('ABCD'))

# %%
rm
# Out:
#       A    B    C    D
# 0   154  140   94  198
# 1    66  191  270  180
# 2   235  283    0    4
# 3    12  226   26  233
# 4   174  221  215  202
# 5    41   67    4  145
# 6    32  266   51  146
# 7   136   12  294  138
# 8    67  211   34  230
# 9    44    5   82  151
# 10  221   88    4  214
# 11  245  296  265  181
# 12   38  202  189  164
# 13  148  102  142  286
# 14   10  189  299  152
# 15  225  270   64  201
# 16  175   41  298  274
# 17   17  280  227   37
# 18   52  257   46  112
# 19   99   49  216  111

# %%
rm.to_csv('random.csv')

# %%
dt=pd.read_csv('random.csv')

# %%
dt
# Out:
#     Unnamed: 0    A    B    C    D
# 0            0  154  140   94  198
# 1            1   66  191  270  180
# 2            2  235  283    0    4
# 3            3   12  226   26  233
# 4            4  174  221  215  202
# 5            5   41   67    4  145
# 6            6   32  266   51  146
# 7            7  136   12  294  138
# 8            8   67  211   34  230
# 9            9   44    5   82  151
# 10          10  221   88    4  214
# 11          11  245  296  265  181
# 12          12   38  202  189  164
# 13          13  148  102  142  286
# 14          14   10  189  299  152
# 15          15  225  270   64  201
# 16          16  175   41  298  274
# 17          17   17  280  227   37
# 18          18   52  257   46  112
# 19          19   99   49  216  111
